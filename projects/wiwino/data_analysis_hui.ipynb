# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect('db/vivino.db')

# %%
cursor = connection.cursor()
print("Connected to the database")
# Out:
# Connected to the database

# %%
Query_1 = """
SELECT DISTINCT name
FROM regions;
"""
cursor.execute(Query_1)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df1 = pd.DataFrame(results, columns=columns)

print(df1)
# Out:
#                                          name
# 0                             South Australia
# 1                                  California
# 2                                 Napa Valley
# 3                               Sonoma County
# 4                                    Oakville
# ..                                        ...
# 256               Champagne Grand Cru 'Avize'
# 257  Champagne Grand Cru 'Le Mesnil-sur-Oger'
# 258                       Champagne Grand Cru
# 259                     Champagne Premier Cru
# 260                             Apalta Valley
#
# [261 rows x 1 columns]

# %%
Query_2 = """
SELECT *
FROM vintages
WHERE ratings_average >= 4.8
ORDER BY ratings_average DESC
;
"""
cursor.execute(Query_2)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df2 = pd.DataFrame(results, columns=columns)

print(df2)
# Out:
#            id                                               name  wine_id  \
# 0     1443139  Château Doisy-Daëne L'Extravagant de Doisy-Daë...    96337
# 1     8519046   Biondi-Santi Brunello di Montalcino Riserva 1955    82698
# 2       93707  Château Lafite Rothschild Pauillac (Premier Gr...     3908
# 3     1137877                           Krug Clos du Mesnil 1998    79635
# 4     1161459  Salon Le Mesnil Blanc de Blancs (Cuvée S) Brut...  1127349
# 5     1265300  Dal Forno Romano Amarone della Valpolicella Mo...    89750
# 6     1384432               Harlan Estate Harlan Estate Red 1998  1218210
# 7     1688597                           Krug Clos du Mesnil 2000    79635
# 8     1791320         Quinta do Noval Vintage Port Nacional 2001    81431
# 9     1889890                                Pétrus Pomerol 1990  1166837
# 10    1902564                     Château d'Yquem Sauternes 1967  1153863
# 11    2047023        Dal Forno Romano Nettare Veneto Bianco 1995  1476033
# 12    2369356   Quintarelli Giuseppe Veneto Alzero Cabernet 2011  1194532
# 13    2423072   Quintarelli Giuseppe Veneto Alzero Cabernet 2009  1194532
# 14    2641965  Château Latour Grand Vin Pauillac (Premier Gra...  1655970
# 15    2858500       Clos Rougeard Le Bourg Saumur Champigny 2013  1101360
# 16    2890763  Quintarelli Giuseppe Amarone della Valpolicell...    84065
# 17    4064906  Joseph Drouhin Montrachet Grand Cru Marquis de...  1274124
# 18    6880159                               Masseto Toscana 2006  2446729
# 19    6988511                               Masseto Toscana 2005  2446729
# 20    7201085                               Masseto Toscana 2001  2446729
# 21    8243664                               Masseto Toscana 2002  2446729
# 22   14187320                  Scarecrow Cabernet Sauvignon 2015  1611255
# 23   14207721                     Château d'Yquem Sauternes 2015  1153863
# 24   56350333  Joseph Drouhin Montrachet Grand Cru Marquis de...  1274124
# 25  103459705                          Colgin IX Estate Red 2016     8023
# 26  127064316       Giacomo Conterno Barolo Cascina Francia 2016    82203
# 27  131862469  Casanova di Neri Cerretalto Brunello di Montal...    81836
# 28  133317107      Domaine Jacques Prieur Musigny Grand Cru 2015    16529
# 29  143906565  Joseph Drouhin Montrachet Grand Cru Marquis de...  1274124
# 30  150313476                     Château d'Yquem Sauternes 2017  1153863
# 31  150679517  Joseph Drouhin Montrachet Grand Cru Marquis de...  1274124
# 32  156114443  Château Ausone Saint-Émilion Grand Cru (Premie...  1152417
# 33  156217121                          Artadi Viña El Pison 2018    49754
# 34  156265675  Domaine du Clos de Tart Clos de Tart Grand Cru...  1186041
# 35  160638052             Louis Roederer Cristal Vinothèque 1999  7219675
#
#     ratings_average  ratings_count  year  price_euros price_discounted_from  \
# 0               4.9             32  2001       397.50                  None
# 1               4.9             35  1955      1970.05                  None
# 2               4.8           1000  2003      1900.00                  None
# 3               4.8            235  1998      3522.50                  None
# 4               4.8           1004  1996      2882.50                  None
# 5               4.8             88  1995       808.75                  None
# 6               4.8            104  1998      1921.25                  None
# 7               4.8            333  2000      3096.25                  None
# 8               4.8             52  2001      1152.50                  None
# 9               4.8           1190  1990      6300.00                  None
# 10              4.8            330  1967      2455.00                  None
# 11              4.8             38  1995       310.00                  None
# 12              4.8             82  2011       913.05                  None
# 13              4.8            208  2009       555.00                  None
# 14              4.8            920  2003      1686.25                  None
# 15              4.8             54  2013       832.50                  None
# 16              4.8            444  2013       425.00                  None
# 17              4.8             59  2014      2028.75                  None
# 18              4.8            797  2006      4910.00                  None
# 19              4.8            762  2005      4697.50                  None
# 20              4.8            651  2001      5231.25                  None
# 21              4.8            490  2002      1686.25                  None
# 22              4.8            243  2015      1558.75                  None
# 23              4.8            763  2015       811.25                  None
# 24              4.8             92  2015      1601.25                  None
# 25              4.8            131  2016       745.00                  None
# 26              4.8            214  2016       705.00                  None
# 27              4.8            175  2016       379.00                  None
# 28              4.8             39  2015      1199.00                  None
# 29              4.8             51  2016      1691.25                  None
# 30              4.8            334  2017       832.50                  None
# 31              4.8            137  2017       811.80                  None
# 32              4.8             31  2018      1625.00                  None
# 33              4.8             64  2018       437.50                  None
# 34              4.8             38  2018      1473.75                  None
# 35              4.8             41  1999      2113.75                  None
#
#    price_discount_percentage  bottle_volume_ml
# 0                       None               375
# 1                       None               750
# 2                       None               750
# 3                       None               750
# 4                       None               750
# 5                       None               750
# 6                       None               750
# 7                       None               750
# 8                       None               750
# 9                       None               750
# 10                      None               750
# 11                      None               375
# 12                      None              1500
# 13                      None               750
# 14                      None               750
# 15                      None               750
# 16                      None               750
# 17                      None               750
# 18                      None              1500
# 19                      None              1500
# 20                      None              1500
# 21                      None               750
# 22                      None               750
# 23                      None               750
# 24                      None               750
# 25                      None               750
# 26                      None               750
# 27                      None               750
# 28                      None               750
# 29                      None               750
# 30                      None               750
# 31                      None               750
# 32                      None               750
# 33                      None               750
# 34                      None               750
# 35                      None               750

# %%
Query_3 = """
SELECT *
FROM wines
WHERE ratings_average >= 4.7
ORDER BY ratings_average DESC;
"""
cursor.execute(Query_3)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df3 = pd.DataFrame(results, columns=columns)

print(df3)
# Out:
#          id                                               name  is_natural  \
# 0   1187886        Amarone della Valpolicella Classico Riserva           0
# 1   1611255                                 Cabernet Sauvignon           0
# 2   5806244                                             Mágico           0
# 3   6534388                         Fratini Bolgheri Superiore           0
# 4   7266631                            Cristal Rosé Vinothèque           0
# 5   9330771                        Batard-Montrachet Grand Cru           0
# 6      8023                                      IX Estate Red           0
# 7     66294               Special Selection Cabernet Sauvignon           0
# 8     77136                     Unico Reserva Especial Edición           0
# 39        533       2510              4.7            476
# 40        544      47408              4.7            374
# 41       1804       1499              4.7            315
# 42        545       2338              4.7             44
# 43       3237       1653              4.7            574
# 44        394     227918              4.7            186
# 45        409       1235              4.7            426
# 46        535       7636              4.7             76
#
#                                                   url   acidity  fizziness  \
# 0   https://www.seulementproduitsitaliens.be/spec_...  2.427803        NaN
# 1   https://www.seulementproduitsitaliens.be/spec_...  3.304091        NaN
# 2   https://www.grandcruwijnen.nl/2019-sierra-cant...  3.609973        NaN
# 3   https://www.seulementproduitsitaliens.be/vino/...  3.306484        NaN
# 4               http://www.vivino.com/wines/162180364  4.536111   4.192500
# 5   https://hermanwines.com/products/batard-montra...  3.287857        NaN
# 6   https://www.grandcruwijnen.nl/2016-colgin-ix-i...  3.829068        NaN
# 7   https://www.seulementproduitsitaliens.be/spec_...  3.309514        NaN
# 8   https://hermanwines.com/products/reserva-espec...  3.680081        NaN
# 9   https://hermanwines.com/products/unico-vega-si...  3.704849        NaN
# 10  https://www.labuenavida.be/spaanse-wijn/oremus...       NaN        NaN
# 11  https://www.seulementproduitsitaliens.be/spec_...  4.542271   4.393909
# 12  https://www.seulementproduitsitaliens.be/spec_...  4.546456   4.223847
# 13  https://www.seulementproduitsitaliens.be/spec_...  3.261597        NaN
# 14  https://www.seulementproduitsitaliens.be/spec_...  3.836237        NaN
# 15  https://www.seulementproduitsitaliens.be/spec_...  4.513654        NaN
# 16  https://www.seulementproduitsitaliens.be/spec_...  4.108734        NaN
# 17  https://www.seulementproduitsitaliens.be/spec_...  2.360964        NaN
# 18  https://www.seulementproduitsitaliens.be/spec_...  3.097061        NaN
# 19  https://www.seulementproduitsitaliens.be/spec_...  4.125960        NaN
# 20  https://www.seulementproduitsitaliens.be/spec_...  2.235851        NaN
# 21  https://www.seulementproduitsitaliens.be/spec_...  4.508223   4.352797
# 22  https://www.seulementproduitsitaliens.be/spec_...  3.046586        NaN
# 23  https://www.seulementproduitsitaliens.be/spec_...  4.338159        NaN
# 24                http://www.vivino.com/wines/1941165  3.377399        NaN
# 25  https://www.seulementproduitsitaliens.be/spec_...  2.923187        NaN
# 26  https://www.seulementproduitsitaliens.be/spec_...       NaN        NaN
# 27  https://hermanwines.com/products/alzero-quinta...  2.300103        NaN
# 28  https://www.seulementproduitsitaliens.be/eccel...  3.401521        NaN
# 29  https://www.seulementproduitsitaliens.be/spec_...  3.847761        NaN
# 30  https://www.seulementproduitsitaliens.be/spec_...  2.297532        NaN
# 31  https://www.seulementproduitsitaliens.be/spec_...  3.243087        NaN
# 32  https://hermanwines.com/products/harlequin-zym...  2.653078        NaN
# 33  https://hermanwines.com/products/echezeaux-gc-...  4.273491        NaN
# 34  https://joyvino.be/products/de-toren-book-17-2019  3.737392        NaN
# 35  https://www.labuenavida.be/spaanse-wijn/toro-a...  2.244287        NaN
# 36  https://www.seulementproduitsitaliens.be/spec_...  3.102859        NaN
# 37              http://www.vivino.com/wines/162494158  4.272861   4.240509
# 38  https://www.seulementproduitsitaliens.be/spec_...       NaN        NaN
# 39  https://www.wijnkooperijdelange.nl/The-Black-L...  3.408501        NaN
# 40  https://www.grandcruwijnen.nl/2019-bodegas-el-...  2.937016        NaN
# 41  https://www.seulementproduitsitaliens.be/vino/...  2.301390        NaN
# 42  https://www.seulementproduitsitaliens.be/spec_...  4.725295        NaN
# 43  https://www.seulementproduitsitaliens.be/spec_...  2.571134        NaN
# 44  https://hermanwines.com/products/permassimo-te...  3.579933        NaN
# 45  https://www.seulementproduitsitaliens.be/spec_...  4.408438   4.195047
# 46  https://www.wijnig.nl/delas-ligne-de-crete-les...  3.648041        NaN
#
#     intensity  sweetness    tannin  user_structure_count
# 0    4.771582   3.421751  2.327957                  21.0
# 1    4.700800   1.758352  3.393993                 295.0
# 2    3.379597   2.085248  4.100873                  42.0
# 3    4.033437   1.394609  3.766797                   9.0
# 4    4.109823        NaN       NaN                  20.0
# 5    3.722000   1.909429       NaN                   5.0
# 6    4.768673   1.844879  3.635063                 102.0
# 7    4.761678   1.916873  3.202532                1866.0
# 8    3.855348   1.834058  3.483004                 528.0
# 9    3.835725   1.781248  3.419756                2493.0
# 10        NaN        NaN       NaN                   NaN
# 11   4.264712        NaN       NaN                 184.0
# 12   3.965327        NaN       NaN                 338.0
# 13   3.873958   2.033000       NaN                  54.0
# 14   3.505080   1.755017  3.650135                 285.0
# 15   3.747927   1.822810  4.350989                 370.0
# 16   3.023780   1.914556  2.589909                 471.0
# 17   4.597925   3.319350  2.311430                 355.0
# 18   4.346482   2.080589  2.785267                 318.0
# 19   3.148002   1.904137  2.670433                 273.0
# 20   4.817442   3.351203  2.493360                 278.0
# 21   3.999383        NaN       NaN                1119.0
# 22   4.707042   2.106661  3.237850                 505.0
# 23   4.676008   4.870302       NaN                 903.0
# 24   4.131702   1.970729  3.442868                 627.0
# 25   4.669512   2.444670  3.095071                  57.0
# 26        NaN        NaN       NaN                   NaN
# 27   4.123182   2.687513  2.936496                 196.0
# 28   4.126063   1.915546  3.291208                  79.0
# 29   4.689345   1.902386  3.594736                 219.0
# 30   4.634879   3.352047  2.262078                  78.0
# 31   3.886906   1.985579       NaN                  61.0
# 32   4.077545   2.439991  3.081112                 115.0
# 33   2.791203   2.361899  2.546002                  28.0
# 34   4.020132   1.680306  3.420607                  40.0
# 35   4.196692   4.059529       NaN                  23.0
# 36   3.607725   1.977960  3.140429                1114.0
# 37   4.104116        NaN       NaN                1316.0
# 38        NaN        NaN       NaN                   NaN
# 39   4.420351   1.549335  3.272890                  16.0
# 40   4.170016   2.338820  3.658557                   3.0
# 41   4.438854   3.054878  2.411219                  17.0
# 42   3.760588   3.426471       NaN                   7.0
# 43   4.233528   3.203101  2.291238                  41.0
# 44   3.732845   1.290051  3.284798                  35.0
# 45   4.057740        NaN       NaN                  90.0
# 46   4.086487   1.631081  4.212905                   3.0

# %%
Q4 = """
SELECT DISTINCT group_name
FROM keywords_wine
"""
cursor.execute(Q4)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df4 = pd.DataFrame(results, columns=columns)

print(df4)
# Out:
#         group_name
# 0          non_oak
# 1           spices
# 2           floral
# 3      black_fruit
# 4            earth
# 5              oak
# 6         microbio
# 7          vegetal
# 8       tree_fruit
# 9   tropical_fruit
# 10       red_fruit
# 11     dried_fruit
# 12    citrus_fruit

# %%
Q5 = """
SELECT *
FROM keywords
WHERE name IN ('coffee', 'toast', 'green apple', 'cream', 'citrus')
"""
cursor.execute(Q5)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
# 36  169525891  Morlet Family Vineyards Cabernet Sauvignon Coe...    94692
# 37  171909533  Cantina Kurtatsch Freienfeld Cabernet Sauvigno...  7476568
#
#     ratings_average  ratings_count  year  price_euros  price_discounted_from  \
# 0               4.6            299  1997       397.50                    NaN
# 1               4.7             64  2006       201.25                    NaN
# 2               4.5             65  2005       260.00                    NaN
# 3               4.6            125  2008       178.75                    NaN
# 4               4.6             36  2004       221.25                    NaN
# 5               4.5            163  2009       201.25                    NaN
# 6               0.0             24  2001       201.25                    NaN
# 7               4.6             42  2003       201.25                    NaN
# 8               4.4            827  2013       169.75                    NaN
# 9               4.8            243  2015      1558.75                    NaN
# 10              4.4            552  2012       162.15                    NaN
# 11              4.5           3609  2017       137.50                    NaN
# 12              4.7           1890  2017       443.00                    NaN
# 13              4.6            235  2017       295.00                    NaN
# 14              4.4            224  2017       106.00                    NaN
# 15              4.6             56  2017       147.50                    NaN
# 16              4.4            465  2018       119.00                  145.0
# 17              4.6           1081  2018       106.96                    NaN
# 18              4.6            260  2018       360.00                    NaN
# 19              4.4           2594  2018        85.95                    NaN
# 20              4.6            231  2018       199.95                    NaN
# 21              4.4           3867  2018        61.95                    NaN
# 22              4.5            451  2018       175.95                    NaN
# 23              4.5             53  2018       121.95                    NaN
# 24              4.5             98  2018       412.50                    NaN
# 25              4.6            184  2018       275.00                    NaN
# 26              4.6          15647  2019       177.95                    NaN
# 27              4.5            770  2019       125.95                    NaN
# 28              4.5           1765  2019        95.95                    NaN
# 29              4.6            325  2019       199.95                    NaN
# 30              0.0             17  2016       209.05                    NaN
# 31              0.0             11  2019       134.95                    NaN
# 32              4.5             52  2019       195.00                    NaN
# 33              0.0              8  2019        36.30                    NaN
# 34              4.5            627  2020        89.95                    NaN
# 35              4.5             32  2019       154.60                    NaN
# 36              0.0             12  2019       295.00                    NaN
# 37              0.0              1  2000       156.25                    NaN
#
#     price_discount_percentage  bottle_volume_ml
# 0                         NaN               750
# 1                         NaN               750
# 2                         NaN               750
# 3                         NaN               750
# 4                         NaN               750
# 5                         NaN               750
# 6                         NaN               750
# 7                         NaN               750
# 8                         NaN               750
# 9                         NaN               750
# 10                        NaN               750
# 11                        NaN               750
# 12                        NaN              1500
# 13                        NaN               750
# 14                        NaN               750
# 15                        NaN               750
# 16                      17.93               750
# 17                        NaN               750
# 18                        NaN               750
# 19                        NaN               750
# 20                        NaN               750
# 21                        NaN               750
# 22                        NaN               750
# 23                        NaN               750
# 24                        NaN               750
# 25                        NaN               750
# 26                        NaN              1500
# 27                        NaN               750
# 28                        NaN               750
# 29                        NaN               750
# 30                        NaN               750
# 31                        NaN               750
# 32                        NaN               750
# 33                        NaN               750
# 34                        NaN               750
# 35                        NaN               750
# 36                        NaN               750
# 37                        NaN               750

# %%
Q6 = """
SELECT *
FROM wines
WHERE name LIKE '%Cabernet Sauvignon%'
"""
cursor.execute(Q6)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
# 9   https://www.wereldwijnonline.be/fay-cabernet-s...  3.336758      None
# 10  https://www.wereldwijnonline.be/stags-leap-art...  3.383825      None
# 11  https://www.wereldwijnonline.be/stags-leap-slv...  3.407499      None
# 12  https://www.seulementproduitsitaliens.be/eccel...  2.998364      None
# 13  https://www.grandcruwijnen.nl/2018-shafer-vine...  3.620571      None
# 14              http://www.vivino.com/wines/156095222  3.322147      None
# 15  https://www.grandcruwijnen.nl/2019-forman-napa...  3.387184      None
# 16  https://www.grandcruwijnen.nl/2018-quilceda-cr...  3.884835      None
# 17  https://www.wereldwijnonline.be/clos-quebrada-...  3.033497      None
# 18  https://www.vivino.com/BE/en/michael-david-win...  2.968296      None
# 19  https://www.grandcruwijnen.nl/2019-hourglass-c...  3.367740      None
# 20  https://www.seulementproduitsitaliens.be/spec_...  3.304091      None
# 21  https://www.grandcruwijnen.nl/2017-dunn-howell...  3.415652      None
# 22  https://www.wereldwijnonline.be/cask-23-cabern...  3.362243      None
# 23  https://hermanwines.com/products/cabernet-sauv...  3.096885      None
# 24  https://www.seulementproduitsitaliens.be/eccel...  3.292121      None
# 25  https://www.seulementproduitsitaliens.be/eccel...  3.340095      None
# 26  https://hermanwines.com/products/altagracia-ca...  3.505831      None
# 27  https://www.seulementproduitsitaliens.be/spec_...  2.886960      None
# 28                                                  X  3.322194      None
#
#     intensity  sweetness    tannin  user_structure_count
# 0    4.736395   1.590194  3.422338                   811
# 1    4.698095   1.691894  3.236337                  1114
# 2    4.709039   1.690490  3.371491                  1691
# 3    3.928453   2.311101  2.895819                   141
# 4    4.748084   1.936713  3.146816                  6325
# 5    4.761678   1.916873  3.202532                  1866
# 6    4.781501   1.604793  3.312944                    86
# 7    4.612872   1.598290  3.436742                    46
# 8    3.964489   1.540390  3.795511                    67
# 9    4.635712   1.625809  3.262613                   679
# 10   4.730513   1.603856  3.286232                  3174
# 11   4.685556   1.596598  3.389588                   424
# 12   4.711772   1.465726  3.314976                  1655
# 13   4.792717   1.615925  3.469906                   442
# 14   4.675551   1.613046  3.331553                   892
# 15   4.585916   1.659149  3.429642                   225
# 16   3.994474   1.644870  3.914068                   133
# 17   4.318866   1.838132  3.304302                   520
# 18   4.806870   1.694687  3.233641                    88
# 19   4.744083   1.810093  3.455080                   116
# 20   4.700800   1.758352  3.393993                   295
# 21   4.632322   1.626812  3.562164                   510
# 22   4.665351   1.618788  3.334649                   591
# 23   4.536795   1.445688  3.653364                     8
# 24   4.666627   1.661337  3.217009                   189
# 25   4.622090   1.652254  3.392720                    38
# 26   4.779707   1.751252  3.520630                   113
# 27   4.010386   1.922639  3.199599                    36
# 28   4.877959   1.734915  3.730527                    22

# %%
Q8 = """

# %%
Q9 = """
SELECT grapes.name AS grape_name, most_used_grapes_per_country.country_code
FROM grapes
JOIN most_used_grapes_per_country
ON grapes.id = most_used_grapes_per_country.grape_id
WHERE grape_name LIKE '%Cabernet Sauvignon%'
"""
cursor.execute(Q9)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df9 = pd.DataFrame(results, columns=columns)

print(df9)
# Out:
#             grape_name country_code
# 0   Cabernet Sauvignon           us
# 1   Cabernet Sauvignon           es
# 2   Cabernet Sauvignon           au
# 3   Cabernet Sauvignon           hu
# 4   Cabernet Sauvignon           za
# 5   Cabernet Sauvignon           cl
# 6   Cabernet Sauvignon           md
# 7   Cabernet Sauvignon           ar
# 8   Cabernet Sauvignon           gr
# 9   Cabernet Sauvignon           il
# 10  Cabernet Sauvignon           ro
# 11  Cabernet Sauvignon           hr

# %%
Q10 = """
SELECT *
FROM wines

ORDER BY sweetness DESC;
"""
cursor.execute(Q10)
results = cursor.fetchall()
# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a DataFrame using the fetched data and column names
df10 = pd.DataFrame(results, columns=columns)

print(df10)
# Out:
#             id                                               name  is_natural  \
# 0      2267925                             Aszú 6 Puttonyos Tokaj           0
# 1      1297856                                          Sauternes           0
# 2        96337             L'Extravagant de Doisy-Daëne Sauternes           0
# 3      2416580                                      Aszú Eszencia           0
# 4      1958101                   Vin de Constance (Natural Sweet)           0
# ...        ...                                                ...         ...
# 1015   8767321      Fleur de Miraval Exclusivement Rosé Champagne           0
# 1016   9577421  Single Barrel Champagne Grand Cru 'Le Mesnil-s...           0
# 1017  10120230                        Clos Le Léon Dizy Champagne           0
# 1018  10746470                       Academia Purcari Rară Neagră           0
# 1019  11339017  Collection Fût de Chêne Brut Champagne Grand C...           0
#
#       region_id  winery_id  ratings_average  ratings_count  \
# 0           541      88118              4.6             54
# 1           432      52856              4.3            938
# 2           432       1607              4.6            465
# 3           541      21273              4.5            283
# 4           625       2662              4.6          13210
# ...         ...        ...              ...            ...
# 1015        409      26164              4.4            304
# 1016       4631     283629              4.6             34
# 1017        409       6443              4.5             53
# 1018       1124       9534              4.5             73
# 1019       4621       4333              4.5             58
#
#                                                     url   acidity  fizziness  \
# 0     https://www.vinetiq.eu/nl-be/onze-wijnen/honga...  5.000000        NaN
# 1     https://www.colaris.com/catalog/product/view/i...  4.305051        NaN
# 2     https://www.vanoudsdezwaan.nl/chateau-doisy-da...  4.403935        NaN
# 3     https://www.douchywebshop.com/wijnen/witte-wij...  4.794445        NaN
# 4     https://www.topwijnen.be/nl/product/wijnen/zui...  4.958154        NaN
# ...                                                 ...       ...        ...
# 1015  https://www.wijnig.nl/champagne-fleur-de-mirav...  3.986467   4.094708
# 1016  https://hermanwines.com/products/champagne-gc-...  4.910000   4.796364
# 1017  https://www.wijnig.nl/marc-hebrart-clos-le-leo...  4.459422   4.187399
# 1018  https://tezauro.myshopify.com/products/academi...       NaN        NaN
# 1019  https://hermanwines.com/products/ay-gc-fut-de-...  4.537529   4.382784
#
#       intensity  sweetness  tannin  user_structure_count
# 0      3.386813   5.000000     NaN                   0.0
# 1      4.733891   4.989317     NaN                  12.0
# 2      4.838194   4.980402     NaN                  20.0
# 3      2.855555   4.966667     NaN                   1.0
# 4      3.930444   4.960214     NaN                   3.0
# ...         ...        ...     ...                   ...
# 1015   3.693109        NaN     NaN                  64.0
# 1016   4.232500        NaN     NaN                   3.0
# 1017   4.169884        NaN     NaN                  14.0
# 1018        NaN        NaN     NaN                   NaN
# 1019   4.083764        NaN     NaN                  10.0
#
# [1020 rows x 14 columns]
